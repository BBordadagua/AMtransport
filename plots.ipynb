# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
#list(colormaps)

# %%
d=np.genfromtxt("../MESA/history.data", dtype=np.double,skip_header=6)
d=d.T
plt.figure()
plt.plot(d[36],d[37])
plt.plot(d[36][23],d[37][23],marker='.')
plt.xlim(3.85,3.6)
#plt.close()
# Out:
# (3.85, 3.6)

# %%
## plot for the initial conditions of ys

ini=np.genfromtxt("../initial_guess.txt", dtype=np.double)
ini=ini.T 
plt.figure()
plt.plot(ini[1],ini[2])
#plt.yscale('log')
#plt.xscale('log')
#plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$\Omega$ (rad/s)')
#plt.legend()
plt.savefig('debug/y_ini/y1_ini.pdf')
plt.close()

plt.figure()
plt.plot(ini[1],ini[3])
plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
#plt.ylabel(r'$1/\sqrt{\nu} d\Omega/ d\nu$')
plt.savefig('debug/y_ini/y2_ini.pdf')
plt.close()

plt.figure()
plt.plot(ini[1],ini[4])
plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
#plt.ylabel(r'$U_2$')
plt.savefig('debug/y_ini/y3_ini.pdf')
plt.close()

plt.figure()
plt.plot(ini[1],ini[5])
#plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$y_4$')
plt.savefig('debug/y_ini/y4_ini.pdf')
plt.close()

plt.figure()
plt.plot(ini[1],ini[6])
#plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$\Lambda$')
plt.savefig('debug/y_ini/y5_ini.pdf')
plt.close()

# %%
## plot for the diffusion coefficients

iter_fin = 3
plt.figure()
for i in range(1, iter_fin+1, 1):
    diff=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    diff=diff.T 
    plt.plot(diff[0],diff[8],label='Dv iter='+str(i))#,marker='.')
plt.yscale('log')
plt.xscale('log')
#plt.ylim(1e-2,1e8)
plt.ylim(1e-15,1e8)
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('Dv')
plt.legend()
plt.savefig('debug/Diff_coeff/dv.pdf')
plt.close()

plt.figure()
for i in range(1, iter_fin+1, 1):
    diff=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    diff=diff.T 
    plt.plot(diff[0],diff[6],label='Dh iter='+str(i))#,marker='.')
    #plt.plot(diff[0],diff[7],label='Dh_k iter='+str(i))#,marker='.')
    
plt.yscale('log')
plt.xscale('log')
#plt.ylim(1e-2,1e8)
plt.ylim(1e-2,1e8)
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('Dh')
plt.legend()
plt.savefig('debug/Diff_coeff/dh.pdf')
plt.close()

# %%
## plot of the evolution of ys with iteration

iter_fin = 3
plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    plt.plot(data[0],data[1],label=r'$\Omega$ (rad/s) iter='+str(i))
plt.yscale('log')
plt.xscale('log')
#plt.ylim(-2.5e-6,1e-6)
#plt.xscale('log')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('y')
plt.legend()
plt.savefig('debug/y/y1_radius.pdf')
plt.close()

plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    plt.plot(data[0],data[2],label=r'$1/\sqrt{\nu} d\Omega/ d\nu$ iter='+str(i))
#plt.yscale('log')
#plt.xscale('log')
#plt.ylim(-2.5e-6,1e-6)
#plt.xscale('log')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('y')
plt.legend()
plt.savefig('debug/y/y2_radius.pdf')
plt.close()

plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    plt.plot(data[0],data[3],label=r'$U_2$ iter='+str(i))
#plt.yscale('log')
plt.xscale('log')
#plt.ylim(-9e-6,1e-6)
#plt.xscale('log')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('y')
plt.legend()
plt.savefig('debug/y/y3_radius.pdf')
plt.close()

plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    plt.plot(data[0],data[4],label=r'$\Upsilon$ iter='+str(i))
#plt.yscale('log')
#plt.xscale('log')
#plt.ylim(-2.5e-6,1e-6)
#plt.xscale('log')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('y')
plt.legend()
plt.savefig('debug/y/y4_radius.pdf')
plt.close()

plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    plt.plot(data[0],data[5],label=r'$\Lambda$ iter='+str(i))
#plt.yscale('log')
#plt.xscale('log')
#plt.ylim(-2.5e-6,1e-6)
#plt.xscale('log')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel('y')
plt.legend()
plt.savefig('debug/y/y5_radius.pdf')
plt.close()

## Psi
cte=np.genfromtxt("../cte2.txt", dtype=np.double)
cte=cte.T 
plt.figure()
for i in range(1, iter_fin+1, 1):
    data=np.genfromtxt("../output/it"+str(i)+".txt", dtype=np.double)
    data=data.T 
    psi = cte[34]*data[1]*cte[40]*data[2] - cte[31]*data[5] #psi = cte(35,k)*y1*cte(41,k)*y2 - cte(32,k)*y5
    plt.plot(data[0],psi,label=r'$\Psi$ iter='+str(i))
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$\Psi$')
plt.ylim(1e-8,1e-5)
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.savefig('debug/y/Psi_radius.pdf')
plt.close()

# %%
## plot the variables and constants vs radius
d1=np.genfromtxt("../var2.txt", dtype=np.double)
d1=d1.T 
d = np.genfromtxt("var.txt",dtype=str)
d = d.T
nvar = 44
for i in range(0, nvar, 1):
    plt.figure()
    plt.plot(d1[2],d1[i])
    plt.xlabel(r'radius/$R_{\odot}$')
    plt.ylabel(r'${var_name}$'.format(var_name=d[1][i]))
    #plt.yscale('log')
    #plt.xscale('log')
    plt.savefig('debug/var/var'+str(i+1)+r'_{var_name}.pdf'.format(var_name=d[1][i]))
    plt.close()

d2=np.genfromtxt("../cte2.txt", dtype=np.double)
d2=d2.T 
nvar = 56
for i in range(0, nvar, 1):
    plt.figure()
    plt.plot(d1[2],d2[i])
    plt.xlabel(r'radius/$R_{\odot}$')
    plt.ylabel('cte_'+str(i+1))
    plt.savefig('debug/cte/cte'+str(i+1)+'.pdf')
    plt.close()

# %%
## plot for the rotation profile evolution with model

modelini = 23#1101
modelfin = 24#1102
step = 1
mesaprofile = np.genfromtxt("../output/inirot_"+str(modelini)+".txt", dtype=np.double)
mesaprofile = mesaprofile.T

plt.figure()
plt.plot(mesaprofile[0],mesaprofile[5],label=r'$\Omega_{ini}$')
#plt.plot(data1[0],data1[2],label=r'$d\Omega/dr_{ini}$')
modelini = modelini+1

colors = plt.cm.PiYG(np.linspace(0, 1, modelfin+1-modelini))

for i in range(modelini, modelfin+1, step):
    mesaprofile = np.genfromtxt("../output/rot_"+str(i)+".txt", dtype=np.double)
    mesaprofile = mesaprofile.T
    #d1 = np.genfromtxt("../CN/rot_"+str(i)+".txt", dtype=np.double)
    #d1 = d1.T
  
    if (i==modelini):
        plt.plot(mesaprofile[0],(mesaprofile[2]),color=colors[i-modelini],label=r'Relax. dt=7000yr $\nu_{diff}$=1e7')
        #plt.plot(d1[0],(d1[4]),color=colors[i-modelini],linestyle='dashed',label=r'CN dt=700yr $\nu_{diff}$=1e7')

        #plt.plot(mesaprofile[0],abs(mesaprofile[6]),color=colors[i-modelini],label='relax')#,label=r'$d\Omega/dr$')#,marker='o',markersize=1.)
        #plt.plot(mesaprofile[0],abs(mesaprofile[7]),color=colors[i-modelini],label='num',linestyle='dashed')
        #plt.plot(d1[0],abs(d1[6]),color=colors[i-modelini],label='CN',linestyle='dotted')
    else:
        plt.plot(mesaprofile[0],(mesaprofile[2]),color=colors[i-modelini])#,label=r'$\Omega$')#,marker='o',markersize=1.)
        #plt.plot(d1[0]5[0],abs(d1[6]),color=colors[i-modelini],linestyle='dotted')
        
plt.yscale('log')
plt.xscale('log')
#plt.ylim(1e-15,1e-3)
#plt.ylim(-0.002,0.002)
#plt.xlim(1e-9,1e-4)
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$\Omega$ (rad/s)')
plt.legend()

#sm = plt.cm.ScalarMappable(cmap=cm.cool, norm=plt.Normalize(vmin=0, vmax=1))
#plt.colorbar(sm)
plt.savefig('omega_profile.pdf')

# %%
data=np.genfromtxt("../var.txt", dtype=np.double)
data=data.T 
data=np.genfromtxt("../fort.1000", dtype=np.double)
data=data.T 

plt.figure()

#plt.scatter(data[0],data[1],label='1',marker='.')
#plt.scatter(data[0],data[2],label='2',marker='.')
plt.scatter(data[0],data[3],label='3',marker='.')
#plt.plot(data[0],data[4],label='4')
#plt.plot(data[0],data[5],label='5')
#plt.xscale('log')
#plt.yscale('log')
#plt.xlabel(r'm/$M_{\odot}$')
plt.xlabel(r'radius/$R_{\odot}$')
plt.ylabel(r'$U$')
plt.legend()
plt.savefig('y3_ini_details.pdf')
#plt.close()
